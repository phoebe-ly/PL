# %%
已知有阿程、阿力、阿瑤三人,分別分別年齡為34、29、58,他們分別觸犯多條道路交
通管理處罰條例。
甲:第16條裝高音量喇叭或其他生噪音器物,被罰了1600元、
第17條汽不依限期参加定期檢驗或臨时檢驗,被罰1500元、
第62條汽車駕駛人駕駛汽車肇事,被罰了2500元、
第21條未領有駕駛照駕駛小型車或機車被罰10500元
乙:第12條汽車使用吊銷、註銷之牌照,被罰5000元
丙:第82條未經許可在道路擺設攤位,被罰2000元、
第56條在禁止臨時停車處所停車,被罰1000元

# %%
print('觸犯道路交通管理處罰條例人員名單')
p1 = {
'名子':'阿程',
'年齡':34,
'罪責':{"第16條":"裝高音量喇叭或其他生噪音器物","第17條":"汽不依限期参加定期檢驗或臨时檢驗","第62條":"汽車駕駛人駕駛汽車肇事","第21條":"未領有駕駛照駕駛小型車或機車"
},
'罰金總額':{16100}
'詳細內容':{'第16條':1600,'第17條':1500,'第62條':2500,'第21條':10500,}}

p2 = {
'名字':'阿力',
'年齡':29,
'罪責':{"第12條":"汽車使用吊銷、註銷之牌照"},
'罰金總額':{5000}
'詳細內容':{'第12條':5000,}}

p3 = {
'名子':'阿瑤',
'年齡':58,
'罪責':{"第82條":"未經許可在道路擺設攤位",、"第56條":"在禁止臨時停車處所停車",},
'罰金總額':{3000}
'詳細內容':{'第82條':2000'第56條':1000}}

options = input('請輸入: 1.查看阿程資料 2.查看阿力資料 3.查看阿搖 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:')
    if options == '1':
        print('Name:',person1['name'],'\nAge:',person1['age']) #\n分行
        print('共觸犯(條):',person1_guilt_num)
        print('條例內容:') 
        getit(person1_guilt_content) #呼叫函數用for-loop印出person1_guilt_content各項 
        print('罰鍰總額(元):',person1_money_sum)
        print('詳細內容:')
        getit(person1_money_content)
    elif options == '2':
        print('Name:',person2['name'],'\nAge:',person2['age'])
        print('共觸犯(條):',person2_guilt_num)
        print('條例內容:')
        getit(person2_guilt_content)
        print('罰鍰總額(元):',person2_money_sum)
        print('詳細內容:')
        getit(person2_money_content)
    elif options == '3':
        print('Name:',person3['name'],'\nAge:',person3['age'])
        print('共觸犯(條):',person3_guilt_num)
        print('條例內容:')
        getit(person3_guilt_content)
        print('罰鍰總額(元):',person3_money_sum)
        print('詳細內容:')
        getit(person3_money_content)
    elif options == '4':
        print('甲為1，乙為2，丙為3')
        print('(人,犯罪次數)(少->多）')
        print(ranking_g_enumerate_sorted)
    elif options == '5':
        print('甲為1，乙為2，丙為3')
        print('(人,金額)(少->多）')
        print(ranking_m_enumerate_sorted)
    elif options == '6':
        print('Bye bye~~~')
        break
    else:
        print('輸入錯誤，請重新輸入')
        continue
