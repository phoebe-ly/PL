# %%
已知有阿程、阿力、阿瑤三人,分別分別年齡為34、29、58,他們分別觸犯多條道路交
通管理處罰條例。
甲:第16條裝高音量喇叭或其他生噪音器物,被罰了1600元、
第17條汽不依限期参加定期檢驗或臨时檢驗,被罰1500元、
第62條汽車駕駛人駕駛汽車肇事,被罰了2500元、
第21條未領有駕駛照駕駛小型車或機車被罰10500元
乙:第12條汽車使用吊銷、註銷之牌照,被罰5000元
丙:第82條未經許可在道路擺設攤位,被罰2000元、
第56條在禁止臨時停車處所停車,被罰1000元

# %%
print('觸犯道路交通管理處罰條例人員名單')
p1 = {
'名字':['阿程'],
'年齡':[34],
'條例內容':["第16條:裝高音量喇叭或其他生噪音器物","第17條:汽不依限期参加定期檢驗或臨时檢驗","第62條:汽車駕駛人駕駛汽車肇事","第21條:未領有駕駛照駕駛小型車或機車"
],
'罰鍰總額':[16100],
'詳細內容':['第16條:1600','第17條:1500','第62條:2500','第21條:10500']}

p2 = {
'名字':['阿力'],
'年齡':29,
'條例內容':["第12條:汽車使用吊銷、註銷之牌照"],
'罰鍰總額':[5000],
'詳細內容':['第12條:5000']}

p3 = {
'名字':['阿瑤'],
'年齡':58,
'條例內容':["第82條:未經許可在道路擺設攤位","第56條:在禁止臨時停車處所停車"],
'罰鍰總額':[3000],
'詳細內容':['第82條:2000','第56條:1000']}

options = input('請輸入: 1.查看阿程資料 2.查看阿力資料 3.查看阿搖資料 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:')
if options=="1.查看阿程資料":
    print('名字:',p1['名字'],'\n年齡:',p1['年齡'],'\n共觸犯(條):',len(p1['條例內容']),
              '\n條例內容:',p1['條例內容'],'罰鍰總額(元):',p1['罰鍰總額'],p1['詳細內容'])
elif options=="2.查看阿力資料":
    print('名字:',p2['名字'],'\n年齡:',p2['年齡'],'\n共觸犯(條):',len(p2['條例內容']),
              '\n條例內容:',p1['條例內容'],'罰鍰總額(元):',p1['罰鍰總額'],p1['詳細內容'])
elif options=="3.查看阿搖資料":
    print('名字:',p3['名字'],'\n年齡:',p3['年齡'],'\n共觸犯(條):',len(p3['條例內容']),
              '\n條例內容:',p3['條例內容'],'罰鍰總額(元):',p3['罰鍰總額'],p3['詳細內容'])
elif options=="4.犯罪數排名":
    print('阿程，阿力，阿搖')
elif options=="5.累積罰金&罰鍰數排名":
    print('阿程:',p1['罰鍰總額'],'阿力:',p2['罰鍰總額'],'阿搖:',p3['罰鍰總額'])
elif options=="6.結束程式":
    print("end")
else: 
    print('輸入錯誤，請重新輸入')
# Out:
# 觸犯道路交通管理處罰條例人員名單
# 請輸入: 1.查看阿程資料 2.查看阿力資料 3.查看阿搖資料 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:3.查看阿搖資料
# 名字: ['阿瑤']
# 年齡: 58
# 共觸犯(條): 2
# 條例內容: ['第82條:未經許可在道路擺設攤位', '第56條:在禁止臨時停車處所停車'] 罰鍰總額(元): [3000] ['第82條:2000', '第56條:1000']
