# %%
import pandas as pd

# read csv file
dataa = pd.read_csv("File_14618.csv")

# %%
dataa #102年18歲以上人口目前嚼檳榔率-依縣市別分
# Out:
#    依縣市別分by county 有效樣本數Sample Size  男Male(%)  女Female(%)  總計Both(%)
# 0             新北市              899       6.6         0.2        2.5
# 1             臺北市              842       3.2         0.2        1.0
# 2             臺中市            1,703       8.7         0.3        4.1
# 3             臺南市            1,781       6.2         0.2        3.1
# 4             高雄市            1,745       8.6         0.3        4.1
# 5             宜蘭縣              883      11.4         0.6        3.9
# 6             桃園縣              882      11.0         0.3        3.7
# 7             新竹縣              924       7.9         0.5        3.3
# 8             苗栗縣              966      12.7         0.3        4.9
# 9             彰化縣              927       8.4         0.4        3.3
# 10            南投縣              945      12.8         0.9        5.3
# 11            雲林縣              945      14.7         0.4        5.4
# 12            嘉義縣              962      16.9         0.5        6.9
# ...

# %%
dataa[(dataa["女Female(%)"]<1)&(dataa["男Male(%)"]<10)]
# Out:
#    依縣市別分by county 有效樣本數Sample Size  男Male(%)  女Female(%)  總計Both(%)
# 0             新北市              899       6.6         0.2        2.5
# 1             臺北市              842       3.2         0.2        1.0
# 2             臺中市            1,703       8.7         0.3        4.1
# 3             臺南市            1,781       6.2         0.2        3.1
# 4             高雄市            1,745       8.6         0.3        4.1
# 7             新竹縣              924       7.9         0.5        3.3
# 9             彰化縣              927       8.4         0.4        3.3
# 16            澎湖縣              962       9.8         0.0        3.0
# 17            基隆市              817       8.8         0.4        3.0
# 18            新竹市              873       5.9         0.0        2.2
# 19            嘉義市              841       9.9         0.1        3.2

# %%
dataa[(dataa["女Female(%)"]<1)|(dataa["男Male(%)"]<10)]
# Out:
#    依縣市別分by county 有效樣本數Sample Size  男Male(%)  女Female(%)  總計Both(%)
# 0             新北市              899       6.6         0.2        2.5
# 1             臺北市              842       3.2         0.2        1.0
# 2             臺中市            1,703       8.7         0.3        4.1
# 3             臺南市            1,781       6.2         0.2        3.1
# 4             高雄市            1,745       8.6         0.3        4.1
# 5             宜蘭縣              883      11.4         0.6        3.9
# 6             桃園縣              882      11.0         0.3        3.7
# 7             新竹縣              924       7.9         0.5        3.3
# 8             苗栗縣              966      12.7         0.3        4.9
# 9             彰化縣              927       8.4         0.4        3.3
# 10            南投縣              945      12.8         0.9        5.3
# 11            雲林縣              945      14.7         0.4        5.4
# 12            嘉義縣              962      16.9         0.5        6.9
# ...

# %%
dataa[(dataa["女Female(%)"]<1)^(dataa["男Male(%)"]<10)]
# Out:
#    依縣市別分by county 有效樣本數Sample Size  男Male(%)  女Female(%)  總計Both(%)
# 5             宜蘭縣              883      11.4         0.6        3.9
# 6             桃園縣              882      11.0         0.3        3.7
# 8             苗栗縣              966      12.7         0.3        4.9
# 10            南投縣              945      12.8         0.9        5.3
# 11            雲林縣              945      14.7         0.4        5.4
# 12            嘉義縣              962      16.9         0.5        6.9

# %%
dataa[(dataa["女Female(%)"]<1)&(dataa["男Male(%)"]>10)]
# Out:
#    依縣市別分by county 有效樣本數Sample Size  男Male(%)  女Female(%)  總計Both(%)
# 5             宜蘭縣              883      11.4         0.6        3.9
# 6             桃園縣              882      11.0         0.3        3.7
# 8             苗栗縣              966      12.7         0.3        4.9
# 10            南投縣              945      12.8         0.9        5.3
# 11            雲林縣              945      14.7         0.4        5.4
# 12            嘉義縣              962      16.9         0.5        6.9

# %%
dataa[(dataa["男Male(%)"]<10)&(dataa["女Female(%)"]>1)]
# Out:
# Empty DataFrame
# Columns: [依縣市別分by county, 有效樣本數Sample Size, 男Male(%), 女Female(%), 總計Both(%)]
# Index: []
